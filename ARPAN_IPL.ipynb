# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
p=pd.read_csv("/content/ipl.data.csv")

# %%
print(p.info())
print(p.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
print(p.head(5))
# Out:
#    id  season        city       date                  team1  \
# 0   1    2008   Bangalore  4/18/2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  4/19/2008    Chennai Super Kings
# 2   3    2008       Delhi  4/19/2008       Rajasthan Royals
# 3   4    2008      Mumbai  4/20/2008         Mumbai Indians
# 4   5    2008     Kolkata  4/20/2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
print(p.tail(5))
# Out:
#       id  season       city       date                team1  \
# 572  573    2016     Raipur  5/22/2016     Delhi Daredevils
# 573  574    2016  Bangalore  5/24/2016        Gujarat Lions
# 574  575    2016      Delhi  5/25/2016  Sunrisers Hyderabad
# 575  576    2016      Delhi  5/27/2016        Gujarat Lions
# 576  577    2016  Bangalore  5/29/2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
p.nunique()
# Out:
# id                 577
# season               9
# city                30
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              13
# win_by_runs         83
# win_by_wickets      11
# player_of_match    187
# venue               35
# umpire1             43
# umpire2             45
# umpire3              0
# dtype: int64

# %%
p['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
x=sorted(p["season"])
print(x)
# Out:
# [2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2
# ...

# %%
p.sort_values(by='season')
# Out:
#       id  season        city       date                        team1  \
# 0      1    2008   Bangalore  4/18/2008        Kolkata Knight Riders
# 31    32    2008     Chennai  5/10/2008          Chennai Super Kings
# 32    33    2008   Hyderabad  5/11/2008        Kolkata Knight Riders
# 33    34    2008      Jaipur  5/11/2008             Delhi Daredevils
# 34    35    2008  Chandigarh  5/12/2008  Royal Challengers Bangalore
# ..   ...     ...         ...        ...                          ...
# 541  542    2016        Pune  4/29/2016      Rising Pune Supergiants
# 542  543    2016       Delhi  4/30/2016             Delhi Daredevils
# 543  544    2016   Hyderabad  4/30/2016          Sunrisers Hyderabad
# 545  546    2016        Pune   5/1/2016      Rising Pune Supergiants
# 576  577    2016   Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
p = p.drop('city', axis=1)#to delete  the city column
p[0:2]
# Out:
#    id  season       date                  team1                        team2  \
# 0   1    2008  4/18/2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 1   2    2008  4/19/2008    Chennai Super Kings              Kings XI Punjab
#
#                    toss_winner toss_decision  result  dl_applied  \
# 0  Royal Challengers Bangalore         field  normal           0
# 1          Chennai Super Kings           bat  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 0  Kolkata Knight Riders          140               0     BB McCullum
# 1    Chennai Super Kings           33               0      MEK Hussey
#
#                                         venue    umpire1      umpire2  umpire3
# 0                       M Chinnaswamy Stadium  Asad Rauf  RE Koertzen      NaN
# 1  Punjab Cricket Association Stadium, Mohali  MR Benson   SL Shastri      NaN

# %%
p = p.drop([0, 2, 4])#to delete the 0,2,4no. row
p[0:6]
# Out:
#    id  season       date                team1                        team2  \
# 1   2    2008  4/19/2008  Chennai Super Kings              Kings XI Punjab
# 3   4    2008  4/20/2008       Mumbai Indians  Royal Challengers Bangalore
# 5   6    2008  4/21/2008      Kings XI Punjab             Rajasthan Royals
# 6   7    2008  4/22/2008      Deccan Chargers             Delhi Daredevils
# 7   8    2008  4/23/2008  Chennai Super Kings               Mumbai Indians
# 8   9    2008  4/24/2008      Deccan Chargers             Rajasthan Royals
#
#            toss_winner toss_decision  result  dl_applied  \
# 1  Chennai Super Kings           bat  normal           0
# 3       Mumbai Indians           bat  normal           0
# 5      Kings XI Punjab           bat  normal           0
# 6      Deccan Chargers           bat  normal           0
# 7       Mumbai Indians         field  normal           0
# 8     Rajasthan Royals         field  normal           0
#
# ...

# %%
p=pd.read_csv("/content/ipl.data.csv")#to recover it

# %%
p['winning_details'] = p['win_by_runs'].astype(str) + '/' + p['win_by_wickets'].astype(str)
print(p[['winner', 'winning_details']].head(10))
# Out:
#                         winner winning_details
# 0        Kolkata Knight Riders           140/0
# 1          Chennai Super Kings            33/0
# 2             Delhi Daredevils             0/9
# 3  Royal Challengers Bangalore             0/5
# 4        Kolkata Knight Riders             0/5
# 5             Rajasthan Royals             0/6
# 6             Delhi Daredevils             0/9
# 7          Chennai Super Kings             6/0
# 8             Rajasthan Royals             0/3
# 9              Kings XI Punjab            66/0

# %%
grouped= p.groupby(['season', 'winner', 'player_of_match']).size()
print(grouped)
# Out:
# season  winner               player_of_match
# 2008    Chennai Super Kings  JDP Oram             1
#                              L Balaji             1
#                              M Ntini              2
#                              MEK Hussey           1
#                              ML Hayden            1
#                                                  ..
# 2016    Sunrisers Hyderabad  BCJ Cutting          1
#                              DA Warner            3
#                              HM Amla              1
#                              MC Henriques         1
#                              Mustafizur Rahman    1
# Length: 395, dtype: int64

# %%
mode_winner = p['winner'].mode()[0]
print(f"The most frequent winner all over the season is: {mode_winner}")
# Out:
# The most frequent winner all over the season is: Mumbai Indians

# %%
fd= p[(p['season'] >= 2012) & (p['season'] <= 2016)]
w2012_2016 = fd['winner'].mode()[0]
print(f"The most frequent winner from 2012 to 2016 is: {w2012_2016}")
# Out:
# The most frequent winner from 2012 to 2016 is: Mumbai Indians

# %% [markdown]
# _ _ _ _ _ _ _ _ _ _ _ _checking the missing values_ _ _ _ _ _ _ _ _ _ _ _

# %%
p.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# winning_details      0
# dtype: int64

# %%
p.fillna(0, inplace=True)  # here I replace missing values with 0
p.isnull().sum() #now there is no missing values
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# winning_details    0
# dtype: int64

# %% [markdown]
# _ _ _ _ _ _ _ _plots_ _ _ _ _ _ _ _

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(p['season'], p['win_by_runs'])
plt.xlabel('Season')
plt.ylabel('Win by Runs')
plt.title('Scatter Plot of Season vs. Win by Runs')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(x='winner', data=p, order=p['winner'].value_counts().index)
plt.xlabel('Winning Team')
plt.ylabel('Number of Wins')
plt.title('Number of Wins per Team')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 10))
sns.boxplot(x='venue', y='win_by_runs', data=p)
plt.xlabel('Venue')
plt.ylabel('Win by Runs')
plt.title('Distribution of Win by Runs for Different Venues')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='toss_decision', y='win_by_wickets', data=p)
plt.xlabel('Toss Decision')
plt.ylabel('Win by Wickets')
plt.title('Distribution of Win by Wickets for Different Toss Decisions')
plt.show()

# %%
import seaborn as sns

numericcolumns = ['season', 'win_by_runs', 'win_by_wickets']
correlation = p[numericcolumns].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
wins_venue_team = p.groupby(['venue', 'winner']).size().unstack(fill_value=0)
wins_venue_team.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.xlabel('Venue')
plt.ylabel('Number of Wins')
plt.title('Wins by Venue and Team')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='city', data=p, order=p['city'].value_counts().index)
plt.xlabel('Number of Matches')
plt.ylabel('City')
plt.title('Number of Matches Played in Each City')
plt.show()

# %%
toss_decisions = p['toss_decision'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(toss_decisions, labels=toss_decisions.index, autopct='%1.1f%%', startangle=90)
plt.title('Toss Decisions')
plt.show()

# %%
import matplotlib.pyplot as plt
winbyseason_team = p.groupby(['season', 'winner']).size().unstack(fill_value=0)
plt.figure(figsize=(20, 12))
for team in winbyseason_team.columns:
    plt.plot(winbyseason_team.index, winbyseason_team[team], label=team)
plt.ylabel('Team')
plt.xlabel('Season')
plt.title('Wins by Season for Each Team')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
