# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("/content/world.cup.data.csv")
df=pd.DataFrame(data)

# %%
#  i) no of rows and columns
print(len(data))
print(len(data.columns))
# Out:
# 852
# 20

# %%
# ii) print each column name
print(data.columns)
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
# iii) print specific range using slicing
print(data[20:100])
# Out:
#     Year              Datetime                  Stage           Stadium  \
# 20  1934  27 May 1934 - 16:30       Preliminary round          San Siro
# 21  1934  27 May 1934 - 16:30       Preliminary round         Littorale
# 22  1934  27 May 1934 - 16:30       Preliminary round    Giovanni Berta
# 23  1934  27 May 1934 - 16:30       Preliminary round    Luigi Ferraris
# 24  1934  27 May 1934 - 16:30       Preliminary round     Nazionale PNF
# ..   ...                   ...                    ...               ...
# 95  1954  27 Jun 1954 - 17:00          Quarter-finals        Charmilles
# 96  1954  27 Jun 1954 - 17:00          Quarter-finals  Wankdorf Stadium
# 97  1954  30 Jun 1954 - 18:00             Semi-finals         St. Jakob
# 98  1954  30 Jun 1954 - 18:00             Semi-finals       La Pontaise
# 99  1954  03 Jul 1954 - 17:00   Match for third place          Hardturm
#
#          City Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
# iv) summarization statistics
print(data["Away Team Goals"].mean())
print(data["Away Team Goals"].median())
print(data["Away Team Goals"].mode()[0])
print(data["Away Team Goals"].max())
print(data["Away Team Goals"].min())
# Out:
# 1.022300469483568
# 1.0
# 1
# 7
# 0

# %%
#  i) check missing values
print(df.isnull())#show null values
print(df.isnull().sum())#print the sum of null values in a column
# Out:
#       Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0    False     False  False    False  False           False            False
# 1    False     False  False    False  False           False            False
# 2    False     False  False    False  False           False            False
# 3    False     False  False    False  False           False            False
# 4    False     False  False    False  False           False            False
# ..     ...       ...    ...      ...    ...             ...              ...
# 847  False     False  False    False  False           False            False
# 848  False     False  False    False  False           False            False
# 849  False     False  False    False  False           False            False
# 850  False     False  False    False  False           False            False
# 851  False     False  False    False  False           False            False
#
# ...

# %%
# ii) if found in missing numerical values replace it by mean median
# df["Away Team Goals"].fillna(df["Away Team Goals"].mean(),inplace=True)
print(df)
df["Away Team Goals"].fillna(df["Away Team Goals"].median(),inplace=True)
print(df)
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
print(data.shape)
print(data.describe())
# Out:
# (852, 20)
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
print(df["Home Team Goals"].corr(df["Away Team Goals"]))
# Out:
# 0.012473988573227714

# %%
# i) pairplot
sns.pairplot(data=data)
plt.show()

# %%
# ii) Boxplot
sns.boxplot(data=data,x='Attendance')
plt.show()

# %%
#  iii) heatmap
corr = data[["Home Team Goals","Away Team Goals","Attendance"]].corr()
sns.heatmap(corr)
plt.show()

# %%
# iv) Barplot
sns.barplot(data=data['Attendance'])
# Out:
# <Axes: ylabel='Attendance'>

# %%
# v) histogram
sns.histplot(data=data["Attendance"])
# Out:
# <Axes: xlabel='Attendance', ylabel='Count'>

# %%
#vi)distplot
sns.displot(data["Away Team Goals"], bins=10, kde=True)

# %%
# vii) scatterplot
sns.scatterplot(x="Away Team Goals",y="Attendance",data=data)
plt.show()
